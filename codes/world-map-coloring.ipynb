# %%
import geopandas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
countries_continents = pd.read_csv('./countries_communities.csv')
countries_continents.set_index('country', inplace=True)

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
world
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       920938        Oceania                      Fiji    FJI      8374.0
# 1     53950935         Africa                  Tanzania    TZA    150600.0
# 2       603253         Africa                 W. Sahara    ESH       906.5
# 3     35623680  North America                    Canada    CAN   1674000.0
# 4    326625791  North America  United States of America    USA  18560000.0
# ..         ...            ...                       ...    ...         ...
# 172    7111024         Europe                    Serbia    SRB    101800.0
# 173     642550         Europe                Montenegro    MNE     10610.0
# 174    1895250         Europe                    Kosovo    -99     18490.0
# 175    1218208  North America       Trinidad and Tobago    TTO     43570.0
# 176   13026129         Africa                  S. Sudan    SSD     20880.0
#
#                                               geometry
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..                                                 ...
# 172  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
# [177 rows x 6 columns]

# %%
world = world.join(countries_continents, on='iso_a3')

# %%
plt.figure(figsize=(15, 12))
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().set_xticks([])
plt.gca().set_yticks([])
world.plot(column='community', ax = plt.gca(), missing_kwds={'color': 'lightgrey'})
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

# %%
pd.read_csv('../datasets/wits/simulated/nodelist.csv')
# Out:
#     country_iso3     area  industry_of_gdp  merchandise_of_gdp continent  \
# 0            AFG   652225        22.740252           38.704149      Asia
# 1            AGO  1246700        56.026515           78.305971    Africa
# 2            ALB    28748        24.484408           56.862411    Europe
# 3            ARE    83657        58.035599          151.702461      Asia
# 4            ARG  2766889        25.212698           29.871929   America
# ..           ...      ...              ...                 ...       ...
# 169          WSM     2842        18.584138           55.871854   Pacific
# 170          YEM   547244        46.466096           64.046119      Asia
# 171          ZAF  1219912        26.942540           56.012110    Africa
# 172          ZMB   752614        34.444282           68.965619    Africa
# 173          ZWE   390759        21.720292           81.520812    Africa
#
#      population  landlocked  gdp_per_capita  \
# 0      30117411           1      591.162798
# 1      24220660           0     4615.468219
# 2       2905195           0     4437.142885
# 3       8946778           0    39194.672240
# 4      41261490           0    12848.864197
# ..          ...         ...             ...
# 169      187469           0     3933.459357
# 170    23807586           0     1374.621401
# 171    52003759           0     8007.476439
# 172    14023199           1     1672.907535
# 173    12894323           1     1093.653409
#
#      agriculture_forestry_fishing_of_gdp  gdp_growth  gdp_us_dollar  \
# 0                              23.743664    0.426355   1.780429e+10
# 1                               5.845681    3.471976   1.117897e+11
# 2                              18.226765    2.545322   1.289077e+10
# 3                               0.671910    6.930272   3.506660e+11
# 4                               6.998734    6.003952   5.301633e+11
# ..                                   ...         ...            ...
# 169                             8.836995    4.173393   7.374017e+08
# 170                             8.533169  -12.714823   3.272642e+10
# 171                             2.285473    3.284168   4.164189e+11
# 172                             9.648058    5.564602   2.345952e+10
# 173                             8.665865   14.193913   1.410192e+10
#
#       langoff_1  foreign_direct_investment_inflows  inflation_rate  \
# 0       Persian                       5.217342e+07       11.804186
# 1    Portuguese                      -3.023771e+09       13.482468
# 2      Albanian                       1.048707e+09        3.429123
# 3        Arabic                       7.152096e+09        0.877347
# 4       Spanish                       1.083993e+10        9.800000
# ..          ...                                ...             ...
# 169      Samoan                       8.984743e+06        5.235416
# 170      Arabic                      -5.178429e+08       19.543562
# 171     English                       4.139289e+09        5.017158
# 172     English                       1.108500e+09        6.429397
# 173     English                       3.443000e+08        3.466130
#
#      net_barter_of_trade
# 0             144.751869
# 1             244.329152
# 2              94.337202
# 3             176.149781
# 4             160.564925
# ..                   ...
# 169            80.565436
# 170           171.430685
# 171           146.294834
# 172           197.447040
# 173           111.413525
#
# [174 rows x 15 columns]
