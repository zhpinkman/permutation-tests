# %%
x1 = rnorm(200,5,1)
x2 = rnorm(200,5,0.84)
df1 = data.frame(x1,x2)

# %%
mahalanobis(df1, colMeans(df1), cov(df1))
# Out:
#   [1] 0.46665413 6.04083703 1.34488885 0.05663126 4.17801522 0.23998949
#   [7] 4.20905369 1.91833999 5.21947833 0.42248197 0.85302161 1.45142854
#  [13] 2.44978584 0.93393486 0.90051108 0.32928870 0.07328226 2.88181549
#  [19] 0.02228704 2.17409814 5.66364928 7.63028250 4.41992213 0.80155230
#  [25] 1.89953651 2.90897694 1.35043722 0.18874639 1.60335327 9.24432001
#  [31] 0.18123147 0.20601230 0.05168726 0.64779409 1.40103136 1.66326371
#  [37] 0.39247956 3.84901008 8.51185609 1.72195696 2.92438756 0.85983825
#  [43] 1.33617690 3.87573413 0.32811521 1.82679668 6.21030057 1.52069707
#  [49] 2.82859540 6.91241904 1.79759099 1.45253618 0.80091446 3.03327423
#  [55] 1.67091823 2.38226263 1.43706029 0.94088179 0.16478390 0.13888555
#  [61] 1.18338678 0.70110026 1.43393362 2.43596812 0.01818664 7.15296924
#  [67] 0.54322270 0.28946540 0.36473741 0.17414637 1.35178580 8.88772926
#  [73] 1.71887214 0.31595705 0.45711523 0.57225101 0.33543724 0.08812621
# ...

# %%
par(bg = 'white')
plot(data = df1, x = x1, y = x2)
par(new = FALSE)
plot(x = df1[2, ]$x1, y = df1[2, ]$x2, col='red', cex = 2)
# Out:
# Warning message in plot.window(...):
# ""data" is not a graphical parameter"
# Warning message in plot.xy(xy, type, ...):
# ""data" is not a graphical parameter"
# Warning message in axis(side = side, at = at, labels = labels, ...):
# ""data" is not a graphical parameter"
# Warning message in axis(side = side, at = at, labels = labels, ...):
# ""data" is not a graphical parameter"
# Warning message in box(...):
# ""data" is not a graphical parameter"
# Warning message in title(...):
# ""data" is not a graphical parameter"
# plot without title
# plot without title
