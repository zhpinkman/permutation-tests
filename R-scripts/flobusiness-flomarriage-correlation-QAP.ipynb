# %%
library(sna)
library(network) 
library(ergm)
data(florentine)
# Out:
# Loading required package: statnet.common
#
#
# Attaching package: 'statnet.common'
#
#
# The following object is masked from 'package:base':
#
#     order
#
#
# Loading required package: network
#
# network: Classes for Relational Data
# Version 1.16.1 created on 2020-10-06.
# copyright (c) 2005, Carter T. Butts, University of California-Irvine
#                     Mark S. Handcock, University of California -- Los Angeles
#                     David R. Hunter, Penn State University
#                     Martina Morris, University of Washington
#                     Skye Bender-deMoll, University of Washington
#  For citation information, type citation("network").
#  Type help("network-package") to get started.
#
#
# sna: Tools for Social Network Analysis
# Version 2.6 created on 2020-10-5.
# copyright (c) 2005, Carter T. Butts, University of California-Irvine
#  For citation information, type citation("sna").
#  Type help(package="sna") to get started.
#
#
#
# ...

# %%
flobusiness
# Out:
#  Network attributes:
#   vertices = 16
#   directed = FALSE
#   hyper = FALSE
#   loops = FALSE
#   multiple = FALSE
#   bipartite = FALSE
#   total edges= 15
#     missing edges= 0
#     non-missing edges= 15
#
#  Vertex attribute names:
#     priorates totalties vertex.names wealth
#
# No edge attributes

# %%
flomarriage
# Out:
#  Network attributes:
#   vertices = 16
#   directed = FALSE
#   hyper = FALSE
#   loops = FALSE
#   multiple = FALSE
#   bipartite = FALSE
#   total edges= 20
#     missing edges= 0
#     non-missing edges= 20
#
#  Vertex attribute names:
#     priorates totalties vertex.names wealth
#
# No edge attributes

# %%
par(bg = 'white')
plot(flobusiness, label = get.node.attr(flobusiness, 'vertex.names'))
# Out:
# plot without title

# %%
par(bg = 'white')
plot(flomarriage, label = get.node.attr(flomarriage, 'vertex.names'))
# Out:
# plot without title

# %%
gcor(flomarriage,flobusiness)
# Out:
# [1] 0.3718679

# %%
flo.qap <- qaptest(list(flomarriage, flobusiness), gcor, g1=1, g2=2, reps=1000)

# %%
flo.qap
# Out:
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0.002
# 	p(f(perm) <= f(d)): 1

# %%
par(bg = 'white')
plot(flo.qap)
# Out:
# Plot with title "Estimated Density of QAP Replications"

# %%
nl = netlm(flobusiness, flomarriage, reps = 1000)

# %%
summary(nl)
# Out:
# OLS Network Model
#
# Residuals:
#    0%   25%   50%   75%  100%
# -0.40 -0.07 -0.07 -0.07  0.93
#
# Coefficients:
#             Estimate Pr(<=b) Pr(>=b) Pr(>=|b|)
# (intercept) 0.07     0.635   0.365   0.365
# x1          0.33     1.000   0.000   0.000
#
# Residual standard error: 0.3083 on 238 degrees of freedom
# Multiple R-squared: 0.1383 	Adjusted R-squared: 0.1347
# F-statistic: 38.19 on 1 and 238 degrees of freedom, p-value: 2.757e-09
#
#
# Test Diagnostics:
#
# 	Null Hypothesis: qap
# 	Replications: 1000
# 	Coefficient Distribution Summary:
#
#        (intercept)       x1
# Min        0.77046 -2.64575
# 1stQ       2.55939 -0.52183
# Median     2.91079 -0.52183
# Mean       2.91098  0.05389
# 3rdQ       3.41691  0.52183
# Max        4.46669  6.18010
